# %% [markdown]
# ## Import Libraries

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# modeling imports
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV,ElasticNetCV, ElasticNet
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn import metrics
import statsmodels.api as sm

#set_style
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Import raw data

# %%
csv_ames = r'C:\myLib\IOD\Classwork\Mini Project 2\test.csv'.replace('\\','/')

ames = pd.read_csv(csv_ames)

# %% [markdown]
# ## Change columns name to lower case for easier to work

# %%
ames.columns = ames.columns.str.lower().str.replace(' ','_')

# %%
# Increase pandas default max_rows to view all columns
pd.options.display.max_rows = 250
pd.options.display.max_columns = 250

# %% [markdown]
# ## Data Cleaning and EDA

# %%
ames.shape # 878 rows and 80 columns
# Out:
# (878, 80)

# %% [markdown]
# ## Apply same transformations as to model training data

# %% [markdown]
# ## Nulls

# %% [markdown]
# ### Lot Frontage

# %%
# replace np.nan with average for lot_config of that type

ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'Corner'), 'lot_frontage'] = 83.245552
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'CulDSac'), 'lot_frontage'] = 55.228571
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'FR2'), 'lot_frontage'] = 60.836735
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'FR3'), 'lot_frontage'] = 87.000000
ames.loc[(ames['lot_frontage'].isna()) & (ames['lot_config'] == 'Inside'), 'lot_frontage'] = 66.952780

# %% [markdown]
# ### Alley

# %%
ames['alley'] = ames['alley'].replace(np.nan, 'NA')

# %% [markdown]
# ### Masonry veneer type and area

# %%
ames['mas_vnr_type'] = ames['mas_vnr_type'].replace(np.nan, 'None') # replace masonry np.nan with None
ames['mas_vnr_area'] = ames['mas_vnr_area'].replace(np.nan, 0) # replace masonry np.nan with 0

# %% [markdown]
# ### Basement related:
#
# - bsmt_qual (Evaluates the height of the basement),
# - bsmt_cond (Evaluates the general condition of the basement),
# - bsmt_exposure (Refers to walkout or garden level walls)
# - bsmtfin_type_1
# - bsmtfin_sf_1
# - bsmtfin_type_2
# - bsmtfin_sf_2
# - bsmt_unf_sf
# - total_bsmt_sf
# - bsmt_full_bath
# - bsmt_half_bath

# %%
# NA if no basement
basement_to_na = ['bsmt_qual', 'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_type_2']

for i in basement_to_na:
    ames[i] = ames[i].replace(np.nan, 'NA')

# %%
# set basement sqft to 0 IF basement is NA, else drop as incomplete basement data and only 1 null record for each

basement_to_zero = ['bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf', 'bsmtfin_sf_1', 'bsmt_full_bath','bsmt_half_bath']

for i in basement_to_zero:
    ames[i] = ames[i].replace(np.nan, 0)

# %% [markdown]
# ### fireplace_qu

# %%
ames['fireplace_qu'] = ames['fireplace_qu'].replace(np.nan, 'NA') # NA for 'No Fireplace'

# %% [markdown]
# ### Garage related:
#
# - garage_type
# - garage_yr_blt
# - garage_finish
# - garage_cars
# - garage_area
# - garage_qual
# - garage_cond

# %%
# create two lists, one for catagorical and one for numeric

garage_to_na = ['garage_type','garage_finish','garage_qual','garage_cond']

for i in garage_to_na:
    ames[i] = ames[i].replace(np.nan, 'NA')

# %%
garage_to_0 = ['garage_yr_blt','garage_cars', 'garage_area']

for i in garage_to_0:
    ames[i] = ames[i].replace(np.nan, 0)

# %% [markdown]
# ### pool_qc

# %%
for i in ames[(ames['pool_qc'].isna()) & (ames['pool_area'] == 0)]:
    ames['pool_qc'] = ames['pool_qc'].replace(np.nan, 'NA')

# %% [markdown]
# ### fence

# %%
ames['fence'] = ames['fence'].replace(np.nan, 'NA')

# %% [markdown]
# ### misc_feature

# %%
for i in ames[(ames['misc_feature'].isna()) & (ames['misc_val'] == 0)]:
    ames['misc_feature'] = ames['misc_feature'].replace(np.nan, 'NA')

# %% [markdown]
# ## Final Null Check

# %%
ames.isnull().sum()
# Out:
# id                 0
# pid                0
# ms_subclass        0
# ms_zoning          0
# lot_frontage       0
# lot_area           0
# street             0
# alley              0
# lot_shape          0
# land_contour       0
# utilities          0
# lot_config         0
# land_slope         0
# neighborhood       0
# condition_1        0
# condition_2        0
# bldg_type          0
# house_style        0
# overall_qual       0
# overall_cond       0
# year_built         0
# year_remod/add     0
# roof_style         0
# roof_matl          0
# exterior_1st       0
# exterior_2nd       0
# mas_vnr_type       0
# mas_vnr_area       0
# exter_qual         0
# exter_cond         0
# foundation         0
# bsmt_qual          0
# bsmt_cond          0
# bsmt_exposure      0
# bsmtfin_type_1     0
# bsmtfin_sf_1       0
# bsmtfin_type_2     0
# bsmtfin_sf_2       0
# bsmt_unf_sf        0
# total_bsmt_sf      0
# heating            0
# heating_qc         0
# central_air        0
# electrical         1
# 1st_flr_sf         0
# 2nd_flr_sf         0
# low_qual_fin_sf    0
# gr_liv_area        0
# bsmt_full_bath     0
# bsmt_half_bath     0
# full_bath          0
# half_bath          0
# bedroom_abvgr      0
# kitchen_abvgr      0
# kitchen_qual       0
# totrms_abvgrd      0
# functional         0
# fireplaces         0
# fireplace_qu       0
# garage_type        0
# garage_yr_blt      0
# garage_finish      0
# garage_cars        0
# garage_area        0
# garage_qual        0
# garage_cond        0
# paved_drive        0
# wood_deck_sf       0
# open_porch_sf      0
# enclosed_porch     0
# 3ssn_porch         0
# screen_porch       0
# pool_area          0
# pool_qc            0
# fence              0
# misc_feature       0
# misc_val           0
# mo_sold            0
# yr_sold            0
# sale_type          0
# dtype: int64

# %% [markdown]
# ## Catch anything that was missed

# %%
ames.fillna(0,inplace= True)

# %% [markdown]
# ## Data Transformations to get model features

# %%
#columns I want to replace values in
ames_ordinal_str_columns = ames[['lot_shape','utilities','land_slope','exter_qual','exter_cond','bsmt_qual',
                                 'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1','bsmtfin_type_2','heating_qc',
                                 'electrical','kitchen_qual','functional','fireplace_qu','garage_finish','garage_qual',
                                 'garage_cond','paved_drive','pool_qc','fence']]

dict_ordinal = {
    #overall_qual, overall_cond,exter_qual,exter_cond,bsmt_qual,bsmt_cond,bsmt_exposure,heatingqc,kitchenqual
    #firplacequ,garage_qual,garage_cond,pool_qc,fence
    'Ex': 5,
    'Gd': 4,
    'TA': 3,
    'Fa': 2,
    'Po': 1,
    'NA': 0,
     #lot_shape
    'Reg':4,
    'IR1':3,
    'IR2':2,
    'IR3':1,
    #utilities
    'AllPub':4,
    'NoSewr':3,
    'NoSeWa':2,
    'ELO':1,
    #land_slope
    'Gtl':3,
    'Mod':2,
    'Sev':1,
    #bsmt_exposure
    'Av': 3,
    'Mn': 2,
    'No': 1,
    #bsmtfin_type_1, bsmtfin_type_1
    'GLQ':6,
    'ALQ':5,
    'BLQ':4,
    'Rec':3,
    'LwQ':2,
    'Unf':1,
    #Electrical
    'SBrkr':1,
    'FuseA':0,
    'FuseF':0,
    'FuseP':0,
    'Mix':0,
    #Functional
    'Typ':1,
    'Min1':0,
    'Min2':0,
    'Mod':0,
    'Maj1':0,
    'Maj2':0,
    'Sev':0,
    'Sal':0,
    #garage_finish    
    'Fin': 3,
    'RFn': 2,
    'Unf':1,
    #paved_drive
    'Y' : 2,
    'P' : 1,
    'N' : 0,
    #fence
    'GdPrv':4,
    'MnPrv':3,
    'GdWo':2,
    'MnWw':1   
}

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
# Create neighborhood ranking

ames['neighborhood_order'] = ames['neighborhood']
ames_ordinal_str_columns = ames[['neighborhood_order']]

dict_ordinal = {
    'MeadowV': 1,
    'IDOTRR' : 1,
    'BrDale' : 1,
    'OldTown': 1,
    'BrkSide': 1,
    'Edwards': 1,
    'SWISU': 1,
    'Landmrk':2,
    'Sawyer':2,
    'NPkVill':2,
    'Blueste':2,
    'NAmes':2,
    'Mitchel':2,
    'SawyerW':2,
    'Greens':3,
    'Gilbert':3,
    'NWAmes':3,
    'Blmngtn':3,
    'CollgCr':3,
    'Crawfor':3,
    'ClearCr':3,
    'Somerst':4,
    'Timber':4,
    'Veenker':4,
    'GrnHill':4,
    'StoneBr':4,
    'NoRidge':4,
    'NridgHt':4,
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#Type of sale

ames['sale_type_order'] = ames['sale_type']
ames_ordinal_str_columns = ames[['sale_type_order']]

dict_ordinal = {
   'ConLw':1,
    'Oth':1,
    'ConLD':1,
    'COD':1,
    'WD':2,
    'WD ':2,
    'CWD':3,
    'ConLI':3,
    'Con':3,
    'New':3
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
ames['yr*rem'] = ames['year_remod/add'] * ames['year_built']

# %%
ames['basement_overall'] = ames['bsmt_qual'] *ames['bsmt_exposure']

# %%
ames['bsmt_type*sf_all'] = (ames['bsmtfin_type_1']*ames['bsmtfin_sf_1']) + (ames['bsmtfin_type_2']*ames['bsmtfin_sf_2']) # quality*sf interaction variable

# %%
ames['garage_qual*cond'] = ames['garage_qual']*ames['garage_cond']

# %%
ames['garage_fin*sqft'] = ames['garage_area']*ames['garage_finish']

# %%
#total finished sqft above ground

ames['quality_above_sqft'] = (ames['1st_flr_sf']+ames['2nd_flr_sf']) - ames['low_qual_fin_sf']

# %%
#combine basment baths

ames['bsmt_baths'] = ames['bsmt_full_bath']+(ames['bsmt_half_bath']/2)

# %%
#combine upstairs baths

ames['above_baths'] = ames['full_bath']+(ames['half_bath']/2)

# %%
#I like this all bath feature, more how I think about baths in a home.

ames['all_baths'] = ames['above_baths'] + ames['bsmt_baths']

# %%
#sqft per room w/o baths. This performs better than with baths.

ames['room_size'] = ames['gr_liv_area'] / (ames['totrms_abvgrd'])

# %%
#combine different porches as a measure of developed outside space for houses

ames['developed_outside_sf'] = ames['open_porch_sf']+ ames['screen_porch'] + ames['enclosed_porch'] +ames['3ssn_porch'] +ames['wood_deck_sf']

# %%
#dummy for if house has masonry or not

ames['mas_vnr_type_dummy'] = ames['mas_vnr_type']
ames_ordinal_str_columns = ames[['mas_vnr_type_dummy']]

dict_ordinal = {
   'BrkCmn':1,
    'None':0,
    'CBlock':1,
    'BrkFace':1,
    'Stone':1,   
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#age of property at time of sale

ames['age'] = ames['yr_sold'] - ames['year_built']

# %%
#dummy for if property was remodeled

ames['was_remodeled'] =  ames['year_remod/add'] - ames['year_built'] 
ames['was_remodeled'] = [1 if i> 0 else 0 for i in ames['was_remodeled']];

# %%
#dummy for if property is residential

ames['is_residential'] = ames['ms_zoning']
ames_ordinal_str_columns = ames[['is_residential']]

dict_ordinal = {
   'A (agr)':0,
    'I (all)':0,
    'C (all)':0,
    'RM':1,
    'RH':1,
    'RL':1,
    'FV':1,
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#2 if by positive feature, 1 if normal, 0 if negative feature. 

ames['positive_condition1'] = ames['condition_1']
ames['positive_condition2'] = ames['condition_2']
ames_ordinal_str_columns = ames[['positive_condition2', 'positive_condition1']]


dict_ordinal = {
   'Artery':0,
    'RRNe':0,
    'RRAe':0,
    'Feedr':0,
    'RRAn':0,
    'Norm':1,
    'RRNn':0,
    'PosN':2,
    'PosA':2,
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#combine conditions for a local_condition column

ames['local_conditions'] = ames['positive_condition1']+ames['positive_condition2']

# %%
#Order Exterior house features 

ames['exterior_ordinal1'] = ames['exterior_1st']
ames['exterior_ordinal2'] = ames['exterior_2nd']
ames_ordinal_str_columns = ames[['exterior_ordinal2', 'exterior_ordinal1']]

dict_ordinal = {
    'AsphShn':1,
    'CBlock':1,
    'AsbShng':1,
    'Brk Cmn':2,
    'BrkComm':2,
     'Stucco':2,
    'PreCast':2,
    'Other':3,
    'Wd Shng':3,
    'Wd Sdng':3,
    'MetalSd':3,
    'WdShing':3,
    'HdBoard':3,      
    'Plywood':4,
    'BrkFace':5,       
    'VinylSd':5,
    'CmentBd':5,
    'CemntBd':5,
    'Stone':5,    
    'ImStucc':5,    
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#combine external ordered house features

ames['external_feature'] = ames['exterior_ordinal1'] + ames['exterior_ordinal2']

# %%
ames = pd.get_dummies(data = ames, columns=['bldg_type'], drop_first=True)

# %%
# dummy for hip/nicer roof styles

ames['is_hip_roof'] = ames['roof_style'] 
ames_ordinal_str_columns = ames[['is_hip_roof']]

dict_ordinal = {
    'Gambrel':0,
    'Mansard':0,
    'Gable':0,
    'Flat':1,
    'Shed':1,
     'Hip':1,   
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
# bin before dummy. 

ames['house_style_condensed'] = ames['house_style'] 
ames_ordinal_str_columns = ames[['house_style_condensed']]

dict_ordinal = {
    '1.5Unf':1.5,
    '1.5Fin':1.5,
    'SFoyer':1.5,
    'SLvl':1,
    '1Story':1,
     '2.5Unf':2,
    '2Story':2,
    '2.5Fin':2    
        }

# %%
for i in ames_ordinal_str_columns.columns:
    ames.replace({i: dict_ordinal},inplace = True)

# %%
#dummy building type

ames = pd.get_dummies(data = ames, columns=['house_style_condensed'], drop_first=True)

# %%
#set ames_eval to the features wanted for model

ames_eval = ames[['id','age','neighborhood_order','local_conditions','was_remodeled','overall_qual', 
                  'house_style_condensed_1.5', 'house_style_condensed_2.0','exter_qual','external_feature',
                  'bldg_type_TwnhsE','bldg_type_Twnhs','bldg_type_2fmCon', 'is_hip_roof','mas_vnr_area',  
                  'functional', 'lot_frontage', 'lot_area','developed_outside_sf'
                  ,'garage_fin*sqft','garage_cars', 'paved_drive',
                 'bsmt_qual','bsmt_type*sf_all', 'bsmt_exposure',
                 'heating_qc','kitchen_qual', 'fireplace_qu', 
                 'quality_above_sqft', 'totrms_abvgrd', 'room_size']]

# %%
save_csv_ames = r'C:\myLib\IOD\Classwork\Mini Project 2\ames_test_clean.csv'.replace('\\','/')
ames_eval.to_csv(save_csv_ames, index = False)

# %% [markdown]
# ## Read in clean training dataset

# %%
csv_ames = r'C:\myLib\IOD\Classwork\Mini Project 2\ames_train_clean.csv'.replace('\\','/')
ames_clean = pd.read_csv(csv_ames)

# %%
X_train = ames_clean.drop(columns=['saleprice'])
y_train = ames_clean['saleprice']
X_test = ames_eval.drop(columns= ['id'])

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (2033, 30)
# (2033,)
# (878, 30)

# %% [markdown]
# ## LassoCV Model

# %%
lasso_poly_pipe = Pipeline([
    ('poly', PolynomialFeatures(degree = 2)), 
    ('sc', StandardScaler()),
    ('lassocv', Lasso())
])

lasso_poly_params = {'lassocv__alpha':np.logspace(1, 2.5, 100),
                     'lassocv__max_iter':[10000],
                     'lassocv__tol':[.005]
                    }

pipe_gridsearch = GridSearchCV(lasso_poly_pipe, 
                                param_grid=lasso_poly_params
                              )

# %%
pipe_gridsearch.fit(X_train, y_train)
pipe_gridsearch.best_estimator_
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()), ('sc', StandardScaler()),
#                 ('lassocv',
#                  Lasso(alpha=123.28467394420659, max_iter=10000, tol=0.005))])

# %%
pipe_gridsearch.best_score_
# Out:
# 0.9203527482285768

# %%
X_test.shape
# Out:
# (878, 30)

# %%
preds_lasso = pipe_gridsearch.predict(X_test)

# %%
ames_eval['SalePrice'] = preds_lasso
# Out:
# C:\Users\KELVIN~1.LIE\AppData\Local\Temp/ipykernel_21472/684255210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ames_eval['SalePrice'] = preds_lasso

# %%
lasso_submission = ames_eval[['id', 'SalePrice']]

# %%
lasso_submission.head(3)
# Out:
#      id      SalePrice
# 0  2658  114168.253011
# 1  2718  171495.632156
# 2  2414  215963.680264

# %%
csv_ames = r'C:\myLib\IOD\Classwork\Mini Project 2\ames_submission_lasso.csv'.replace('\\','/')
lasso_submission.to_csv(csv_ames, index = False)

# %% [markdown]
# ## Lasso Coef_ Evaluation

# %%
sc_lasso = StandardScaler()
sc_lasso.fit_transform(X_train)
# Out:
# array([[-0.07300932, -0.35530817, -2.20997115, ...,  0.00951839,
#         -0.26508589,  0.3421764 ],
#        [-0.77235568, -0.35530817,  0.26680468, ...,  1.37130231,
#          1.05904093,  0.76130187],
#        [ 0.69294147, -0.35530817,  0.26680468, ..., -0.88421849,
#         -0.9271493 , -0.44242649],
#        ...,
#        [ 1.49219446,  0.58401759,  0.26680468, ...,  0.92866959,
#          1.72110434, -0.41659594],
#        [ 0.55973263, -0.35530817,  0.26680468, ..., -0.58136452,
#         -0.26508589, -0.69725478],
#        [-0.8389601 ,  0.58401759,  0.26680468, ...,  0.69782286,
#          0.39697752,  0.59285335]])

# %%
lasso_lasso= Lasso(alpha = .1, max_iter=10000)

# %%
lasso_lasso.fit(X_train, y_train)
lasso_lasso.score(X_train, y_train)
# Out:
# 0.898800219398213

# %%
pd.DataFrame(list(zip(X_train.columns, lasso_lasso.coef_)))
# Out:
#                             0             1
# 0                         age    -40.673265
# 1          neighborhood_order   7225.984291
# 2            local_conditions   8256.696654
# 3               was_remodeled   5096.613503
# 4                overall_qual  10058.479053
# 5   house_style_condensed_1.5  -1068.313414
# 6   house_style_condensed_2.0  -9940.774710
# 7                  exter_qual  11692.313909
# 8            external_feature    973.872971
# 9            bldg_type_TwnhsE -12544.821599
# 10            bldg_type_Twnhs -10140.807160
# 11           bldg_type_2fmCon  -6207.359031
# 12                is_hip_roof   5515.555052
# 13               mas_vnr_area     22.491990
# 14                 functional  12463.891852
# 15               lot_frontage    105.464881
# 16                   lot_area      0.519459
# 17       developed_outside_sf     16.063530
# 18            garage_fin*sqft      8.716318
# 19                garage_cars   1668.623531
# 20                paved_drive    205.255283
# 21                  bsmt_qual   2308.297251
# 22           bsmt_type*sf_all      4.723407
# 23              bsmt_exposure   2648.883920
# 24                 heating_qc   1962.763017
# 25               kitchen_qual   9685.730392
# 26               fireplace_qu   1951.870958
# 27         quality_above_sqft     40.947431
# 28              totrms_abvgrd   1997.553625
# 29                  room_size     61.061606

# %% [markdown]
# ## LassoCV with Polynomial Features coef_ evaluation

# %%
# Instantiate our PolynomialFeatures object to create all two-way terms.
poly = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)

# Fit and transform our X data.
X_overfit = poly.fit_transform(X_train)

# %%
#Uncomment to review all features that were created

poly.get_feature_names(X_train.columns)
# Out:
# ['age',
#  'neighborhood_order',
#  'local_conditions',
#  'was_remodeled',
#  'overall_qual',
#  'house_style_condensed_1.5',
#  'house_style_condensed_2.0',
#  'exter_qual',
#  'external_feature',
#  'bldg_type_TwnhsE',
#  'bldg_type_Twnhs',
#  'bldg_type_2fmCon',
#  'is_hip_roof',
#  'mas_vnr_area',
#  'functional',
#  'lot_frontage',
#  'lot_area',
#  'developed_outside_sf',
#  'garage_fin*sqft',
#  'garage_cars',
#  'paved_drive',
#  'bsmt_qual',
#  'bsmt_type*sf_all',
#  'bsmt_exposure',
#  'heating_qc',
#  'kitchen_qual',
#  'fireplace_qu',
#  'quality_above_sqft',
#  'totrms_abvgrd',
#  'room_size',
#  'age^2',
#  'age neighborhood_order',
#  'age local_conditions',
#  'age was_remodeled',
#  'age overall_qual',
#  'age house_style_condensed_1.5',
#  'age house_style_condensed_2.0',
#  'age exter_qual',
#  'age external_feature',
#  'age bldg_type_TwnhsE',
#  'age bldg_type_Twnhs',
#  'age bldg_type_2fmCon',
#  'age is_hip_roof',
#  'age mas_vnr_area',
#  'age functional',
#  'age lot_frontage',
#  'age lot_area',
#  'age developed_outside_sf',
#  'age garage_fin*sqft',
#  'age garage_cars',
#  'age paved_drive',
#  'age bsmt_qual',
#  'age bsmt_type*sf_all',
#  'age bsmt_exposure',
#  'age heating_qc',
#  'age kitchen_qual',
#  'age fireplace_qu',
#  'age quality_above_sqft',
#  'age totrms_abvgrd',
#  'age room_size',
#  'neighborhood_order^2',
#  'neighborhood_order local_conditions',
#  'neighborhood_order was_remodeled',
#  'neighborhood_order overall_qual',
#  'neighborhood_order house_style_condensed_1.5',
#  'neighborhood_order house_style_condensed_2.0',
#  'neighborhood_order exter_qual',
#  'neighborhood_order external_feature',
#  'neighborhood_order bldg_type_TwnhsE',
#  'neighborhood_order bldg_type_Twnhs',
#  'neighborhood_order bldg_type_2fmCon',
#  'neighborhood_order is_hip_roof',
#  'neighborhood_order mas_vnr_area',
#  'neighborhood_order functional',
#  'neighborhood_order lot_frontage',
#  'neighborhood_order lot_area',
#  'neighborhood_order developed_outside_sf',
#  'neighborhood_order garage_fin*sqft',
#  'neighborhood_order garage_cars',
#  'neighborhood_order paved_drive',
#  'neighborhood_order bsmt_qual',
#  'neighborhood_order bsmt_type*sf_all',
#  'neighborhood_order bsmt_exposure',
#  'neighborhood_order heating_qc',
#  'neighborhood_order kitchen_qual',
#  'neighborhood_order fireplace_qu',
#  'neighborhood_order quality_above_sqft',
#  'neighborhood_order totrms_abvgrd',
#  'neighborhood_order room_size',
#  'local_conditions^2',
#  'local_conditions was_remodeled',
#  'local_conditions overall_qual',
#  'local_conditions house_style_condensed_1.5',
#  'local_conditions house_style_condensed_2.0',
#  'local_conditions exter_qual',
#  'local_conditions external_feature',
#  'local_conditions bldg_type_TwnhsE',
#  'local_conditions bldg_type_Twnhs',
#  'local_conditions bldg_type_2fmCon',
#  'local_conditions is_hip_roof',
#  'local_conditions mas_vnr_area',
#  'local_conditions functional',
#  'local_conditions lot_frontage',
#  'local_conditions lot_area',
#  'local_conditions developed_outside_sf',
#  'local_conditions garage_fin*sqft',
#  'local_conditions garage_cars',
#  'local_conditions paved_drive',
#  'local_conditions bsmt_qual',
#  'local_conditions bsmt_type*sf_all',
#  'local_conditions bsmt_exposure',
#  'local_conditions heating_qc',
#  'local_conditions kitchen_qual',
#  'local_conditions fireplace_qu',
#  'local_conditions quality_above_sqft',
#  'local_conditions totrms_abvgrd',
#  'local_conditions room_size',
#  'was_remodeled^2',
#  'was_remodeled overall_qual',
#  'was_remodeled house_style_condensed_1.5',
#  'was_remodeled house_style_condensed_2.0',
#  'was_remodeled exter_qual',
#  'was_remodeled external_feature',
#  'was_remodeled bldg_type_TwnhsE',
#  'was_remodeled bldg_type_Twnhs',
#  'was_remodeled bldg_type_2fmCon',
#  'was_remodeled is_hip_roof',
#  'was_remodeled mas_vnr_area',
#  'was_remodeled functional',
#  'was_remodeled lot_frontage',
#  'was_remodeled lot_area',
#  'was_remodeled developed_outside_sf',
#  'was_remodeled garage_fin*sqft',
#  'was_remodeled garage_cars',
#  'was_remodeled paved_drive',
#  'was_remodeled bsmt_qual',
#  'was_remodeled bsmt_type*sf_all',
#  'was_remodeled bsmt_exposure',
#  'was_remodeled heating_qc',
#  'was_remodeled kitchen_qual',
#  'was_remodeled fireplace_qu',
#  'was_remodeled quality_above_sqft',
#  'was_remodeled totrms_abvgrd',
#  'was_remodeled room_size',
#  'overall_qual^2',
#  'overall_qual house_style_condensed_1.5',
#  'overall_qual house_style_condensed_2.0',
#  'overall_qual exter_qual',
#  'overall_qual external_feature',
#  'overall_qual bldg_type_TwnhsE',
#  'overall_qual bldg_type_Twnhs',
#  'overall_qual bldg_type_2fmCon',
#  'overall_qual is_hip_roof',
#  'overall_qual mas_vnr_area',
#  'overall_qual functional',
#  'overall_qual lot_frontage',
#  'overall_qual lot_area',
#  'overall_qual developed_outside_sf',
#  'overall_qual garage_fin*sqft',
#  'overall_qual garage_cars',
#  'overall_qual paved_drive',
#  'overall_qual bsmt_qual',
#  'overall_qual bsmt_type*sf_all',
#  'overall_qual bsmt_exposure',
#  'overall_qual heating_qc',
#  'overall_qual kitchen_qual',
#  'overall_qual fireplace_qu',
#  'overall_qual quality_above_sqft',
#  'overall_qual totrms_abvgrd',
#  'overall_qual room_size',
#  'house_style_condensed_1.5^2',
#  'house_style_condensed_1.5 house_style_condensed_2.0',
#  'house_style_condensed_1.5 exter_qual',
#  'house_style_condensed_1.5 external_feature',
#  'house_style_condensed_1.5 bldg_type_TwnhsE',
#  'house_style_condensed_1.5 bldg_type_Twnhs',
#  'house_style_condensed_1.5 bldg_type_2fmCon',
#  'house_style_condensed_1.5 is_hip_roof',
#  'house_style_condensed_1.5 mas_vnr_area',
#  'house_style_condensed_1.5 functional',
#  'house_style_condensed_1.5 lot_frontage',
#  'house_style_condensed_1.5 lot_area',
#  'house_style_condensed_1.5 developed_outside_sf',
#  'house_style_condensed_1.5 garage_fin*sqft',
#  'house_style_condensed_1.5 garage_cars',
#  'house_style_condensed_1.5 paved_drive',
#  'house_style_condensed_1.5 bsmt_qual',
#  'house_style_condensed_1.5 bsmt_type*sf_all',
#  'house_style_condensed_1.5 bsmt_exposure',
#  'house_style_condensed_1.5 heating_qc',
#  'house_style_condensed_1.5 kitchen_qual',
#  'house_style_condensed_1.5 fireplace_qu',
#  'house_style_condensed_1.5 quality_above_sqft',
#  'house_style_condensed_1.5 totrms_abvgrd',
#  'house_style_condensed_1.5 room_size',
#  'house_style_condensed_2.0^2',
#  'house_style_condensed_2.0 exter_qual',
#  'house_style_condensed_2.0 external_feature',
#  'house_style_condensed_2.0 bldg_type_TwnhsE',
#  'house_style_condensed_2.0 bldg_type_Twnhs',
#  'house_style_condensed_2.0 bldg_type_2fmCon',
#  'house_style_condensed_2.0 is_hip_roof',
#  'house_style_condensed_2.0 mas_vnr_area',
#  'house_style_condensed_2.0 functional',
#  'house_style_condensed_2.0 lot_frontage',
#  'house_style_condensed_2.0 lot_area',
#  'house_style_condensed_2.0 developed_outside_sf',
#  'house_style_condensed_2.0 garage_fin*sqft',
#  'house_style_condensed_2.0 garage_cars',
#  'house_style_condensed_2.0 paved_drive',
#  'house_style_condensed_2.0 bsmt_qual',
#  'house_style_condensed_2.0 bsmt_type*sf_all',
#  'house_style_condensed_2.0 bsmt_exposure',
#  'house_style_condensed_2.0 heating_qc',
#  'house_style_condensed_2.0 kitchen_qual',
#  'house_style_condensed_2.0 fireplace_qu',
#  'house_style_condensed_2.0 quality_above_sqft',
#  'house_style_condensed_2.0 totrms_abvgrd',
#  'house_style_condensed_2.0 room_size',
#  'exter_qual^2',
#  'exter_qual external_feature',
#  'exter_qual bldg_type_TwnhsE',
#  'exter_qual bldg_type_Twnhs',
#  'exter_qual bldg_type_2fmCon',
#  'exter_qual is_hip_roof',
#  'exter_qual mas_vnr_area',
#  'exter_qual functional',
#  'exter_qual lot_frontage',
#  'exter_qual lot_area',
#  'exter_qual developed_outside_sf',
#  'exter_qual garage_fin*sqft',
#  'exter_qual garage_cars',
#  'exter_qual paved_drive',
#  'exter_qual bsmt_qual',
#  'exter_qual bsmt_type*sf_all',
#  'exter_qual bsmt_exposure',
#  'exter_qual heating_qc',
#  'exter_qual kitchen_qual',
#  'exter_qual fireplace_qu',
#  'exter_qual quality_above_sqft',
#  'exter_qual totrms_abvgrd',
#  'exter_qual room_size',
#  'external_feature^2',
#  'external_feature bldg_type_TwnhsE',
#  'external_feature bldg_type_Twnhs',
#  'external_feature bldg_type_2fmCon',
#  'external_feature is_hip_roof',
#  'external_feature mas_vnr_area',
#  'external_feature functional',
#  'external_feature lot_frontage',
#  'external_feature lot_area',
#  'external_feature developed_outside_sf',
#  'external_feature garage_fin*sqft',
#  'external_feature garage_cars',
#  'external_feature paved_drive',
#  'external_feature bsmt_qual',
#  'external_feature bsmt_type*sf_all',
#  'external_feature bsmt_exposure',
#  'external_feature heating_qc',
#  'external_feature kitchen_qual',
#  'external_feature fireplace_qu',
#  'external_feature quality_above_sqft',
#  'external_feature totrms_abvgrd',
#  'external_feature room_size',
#  'bldg_type_TwnhsE^2',
#  'bldg_type_TwnhsE bldg_type_Twnhs',
#  'bldg_type_TwnhsE bldg_type_2fmCon',
#  'bldg_type_TwnhsE is_hip_roof',
#  'bldg_type_TwnhsE mas_vnr_area',
#  'bldg_type_TwnhsE functional',
#  'bldg_type_TwnhsE lot_frontage',
#  'bldg_type_TwnhsE lot_area',
#  'bldg_type_TwnhsE developed_outside_sf',
#  'bldg_type_TwnhsE garage_fin*sqft',
#  'bldg_type_TwnhsE garage_cars',
#  'bldg_type_TwnhsE paved_drive',
#  'bldg_type_TwnhsE bsmt_qual',
#  'bldg_type_TwnhsE bsmt_type*sf_all',
#  'bldg_type_TwnhsE bsmt_exposure',
#  'bldg_type_TwnhsE heating_qc',
#  'bldg_type_TwnhsE kitchen_qual',
#  'bldg_type_TwnhsE fireplace_qu',
#  'bldg_type_TwnhsE quality_above_sqft',
#  'bldg_type_TwnhsE totrms_abvgrd',
#  'bldg_type_TwnhsE room_size',
#  'bldg_type_Twnhs^2',
#  'bldg_type_Twnhs bldg_type_2fmCon',
#  'bldg_type_Twnhs is_hip_roof',
#  'bldg_type_Twnhs mas_vnr_area',
#  'bldg_type_Twnhs functional',
#  'bldg_type_Twnhs lot_frontage',
#  'bldg_type_Twnhs lot_area',
#  'bldg_type_Twnhs developed_outside_sf',
#  'bldg_type_Twnhs garage_fin*sqft',
#  'bldg_type_Twnhs garage_cars',
#  'bldg_type_Twnhs paved_drive',
#  'bldg_type_Twnhs bsmt_qual',
#  'bldg_type_Twnhs bsmt_type*sf_all',
#  'bldg_type_Twnhs bsmt_exposure',
#  'bldg_type_Twnhs heating_qc',
#  'bldg_type_Twnhs kitchen_qual',
#  'bldg_type_Twnhs fireplace_qu',
#  'bldg_type_Twnhs quality_above_sqft',
#  'bldg_type_Twnhs totrms_abvgrd',
#  'bldg_type_Twnhs room_size',
#  'bldg_type_2fmCon^2',
#  'bldg_type_2fmCon is_hip_roof',
#  'bldg_type_2fmCon mas_vnr_area',
#  'bldg_type_2fmCon functional',
#  'bldg_type_2fmCon lot_frontage',
#  'bldg_type_2fmCon lot_area',
#  'bldg_type_2fmCon developed_outside_sf',
#  'bldg_type_2fmCon garage_fin*sqft',
#  'bldg_type_2fmCon garage_cars',
#  'bldg_type_2fmCon paved_drive',
#  'bldg_type_2fmCon bsmt_qual',
#  'bldg_type_2fmCon bsmt_type*sf_all',
#  'bldg_type_2fmCon bsmt_exposure',
#  'bldg_type_2fmCon heating_qc',
#  'bldg_type_2fmCon kitchen_qual',
#  'bldg_type_2fmCon fireplace_qu',
#  'bldg_type_2fmCon quality_above_sqft',
#  'bldg_type_2fmCon totrms_abvgrd',
#  'bldg_type_2fmCon room_size',
#  'is_hip_roof^2',
#  'is_hip_roof mas_vnr_area',
#  'is_hip_roof functional',
#  'is_hip_roof lot_frontage',
#  'is_hip_roof lot_area',
#  'is_hip_roof developed_outside_sf',
#  'is_hip_roof garage_fin*sqft',
#  'is_hip_roof garage_cars',
#  'is_hip_roof paved_drive',
#  'is_hip_roof bsmt_qual',
#  'is_hip_roof bsmt_type*sf_all',
#  'is_hip_roof bsmt_exposure',
#  'is_hip_roof heating_qc',
#  'is_hip_roof kitchen_qual',
#  'is_hip_roof fireplace_qu',
#  'is_hip_roof quality_above_sqft',
#  'is_hip_roof totrms_abvgrd',
#  'is_hip_roof room_size',
#  'mas_vnr_area^2',
#  'mas_vnr_area functional',
#  'mas_vnr_area lot_frontage',
#  'mas_vnr_area lot_area',
#  'mas_vnr_area developed_outside_sf',
#  'mas_vnr_area garage_fin*sqft',
#  'mas_vnr_area garage_cars',
#  'mas_vnr_area paved_drive',
#  'mas_vnr_area bsmt_qual',
#  'mas_vnr_area bsmt_type*sf_all',
#  'mas_vnr_area bsmt_exposure',
#  'mas_vnr_area heating_qc',
#  'mas_vnr_area kitchen_qual',
#  'mas_vnr_area fireplace_qu',
#  'mas_vnr_area quality_above_sqft',
#  'mas_vnr_area totrms_abvgrd',
#  'mas_vnr_area room_size',
#  'functional^2',
#  'functional lot_frontage',
#  'functional lot_area',
#  'functional developed_outside_sf',
#  'functional garage_fin*sqft',
#  'functional garage_cars',
#  'functional paved_drive',
#  'functional bsmt_qual',
#  'functional bsmt_type*sf_all',
#  'functional bsmt_exposure',
#  'functional heating_qc',
#  'functional kitchen_qual',
#  'functional fireplace_qu',
#  'functional quality_above_sqft',
#  'functional totrms_abvgrd',
#  'functional room_size',
#  'lot_frontage^2',
#  'lot_frontage lot_area',
#  'lot_frontage developed_outside_sf',
#  'lot_frontage garage_fin*sqft',
#  'lot_frontage garage_cars',
#  'lot_frontage paved_drive',
#  'lot_frontage bsmt_qual',
#  'lot_frontage bsmt_type*sf_all',
#  'lot_frontage bsmt_exposure',
#  'lot_frontage heating_qc',
#  'lot_frontage kitchen_qual',
#  'lot_frontage fireplace_qu',
#  'lot_frontage quality_above_sqft',
#  'lot_frontage totrms_abvgrd',
#  'lot_frontage room_size',
#  'lot_area^2',
#  'lot_area developed_outside_sf',
#  'lot_area garage_fin*sqft',
#  'lot_area garage_cars',
#  'lot_area paved_drive',
#  'lot_area bsmt_qual',
#  'lot_area bsmt_type*sf_all',
#  'lot_area bsmt_exposure',
#  'lot_area heating_qc',
#  'lot_area kitchen_qual',
#  'lot_area fireplace_qu',
#  'lot_area quality_above_sqft',
#  'lot_area totrms_abvgrd',
#  'lot_area room_size',
#  'developed_outside_sf^2',
#  'developed_outside_sf garage_fin*sqft',
#  'developed_outside_sf garage_cars',
#  'developed_outside_sf paved_drive',
#  'developed_outside_sf bsmt_qual',
#  'developed_outside_sf bsmt_type*sf_all',
#  'developed_outside_sf bsmt_exposure',
#  'developed_outside_sf heating_qc',
#  'developed_outside_sf kitchen_qual',
#  'developed_outside_sf fireplace_qu',
#  'developed_outside_sf quality_above_sqft',
#  'developed_outside_sf totrms_abvgrd',
#  'developed_outside_sf room_size',
#  'garage_fin*sqft^2',
#  'garage_fin*sqft garage_cars',
#  'garage_fin*sqft paved_drive',
#  'garage_fin*sqft bsmt_qual',
#  'garage_fin*sqft bsmt_type*sf_all',
#  'garage_fin*sqft bsmt_exposure',
#  'garage_fin*sqft heating_qc',
#  'garage_fin*sqft kitchen_qual',
#  'garage_fin*sqft fireplace_qu',
#  'garage_fin*sqft quality_above_sqft',
#  'garage_fin*sqft totrms_abvgrd',
#  'garage_fin*sqft room_size',
#  'garage_cars^2',
#  'garage_cars paved_drive',
#  'garage_cars bsmt_qual',
#  'garage_cars bsmt_type*sf_all',
#  'garage_cars bsmt_exposure',
#  'garage_cars heating_qc',
#  'garage_cars kitchen_qual',
#  'garage_cars fireplace_qu',
#  'garage_cars quality_above_sqft',
#  'garage_cars totrms_abvgrd',
#  'garage_cars room_size',
#  'paved_drive^2',
#  'paved_drive bsmt_qual',
#  'paved_drive bsmt_type*sf_all',
#  'paved_drive bsmt_exposure',
#  'paved_drive heating_qc',
#  'paved_drive kitchen_qual',
#  'paved_drive fireplace_qu',
#  'paved_drive quality_above_sqft',
#  'paved_drive totrms_abvgrd',
#  'paved_drive room_size',
#  'bsmt_qual^2',
#  'bsmt_qual bsmt_type*sf_all',
#  'bsmt_qual bsmt_exposure',
#  'bsmt_qual heating_qc',
#  'bsmt_qual kitchen_qual',
#  'bsmt_qual fireplace_qu',
#  'bsmt_qual quality_above_sqft',
#  'bsmt_qual totrms_abvgrd',
#  'bsmt_qual room_size',
#  'bsmt_type*sf_all^2',
#  'bsmt_type*sf_all bsmt_exposure',
#  'bsmt_type*sf_all heating_qc',
#  'bsmt_type*sf_all kitchen_qual',
#  'bsmt_type*sf_all fireplace_qu',
#  'bsmt_type*sf_all quality_above_sqft',
#  'bsmt_type*sf_all totrms_abvgrd',
#  'bsmt_type*sf_all room_size',
#  'bsmt_exposure^2',
#  'bsmt_exposure heating_qc',
#  'bsmt_exposure kitchen_qual',
#  'bsmt_exposure fireplace_qu',
#  'bsmt_exposure quality_above_sqft',
#  'bsmt_exposure totrms_abvgrd',
#  'bsmt_exposure room_size',
#  'heating_qc^2',
#  'heating_qc kitchen_qual',
#  'heating_qc fireplace_qu',
#  'heating_qc quality_above_sqft',
#  'heating_qc totrms_abvgrd',
#  'heating_qc room_size',
#  'kitchen_qual^2',
#  'kitchen_qual fireplace_qu',
#  'kitchen_qual quality_above_sqft',
#  'kitchen_qual totrms_abvgrd',
#  'kitchen_qual room_size',
#  'fireplace_qu^2',
#  'fireplace_qu quality_above_sqft',
#  'fireplace_qu totrms_abvgrd',
#  'fireplace_qu room_size',
#  'quality_above_sqft^2',
#  'quality_above_sqft totrms_abvgrd',
#  'quality_above_sqft room_size',
#  'totrms_abvgrd^2',
#  'totrms_abvgrd room_size',
#  'room_size^2']

# %%
X_overfit.shape # there are a lot of them
# Out:
# (2033, 495)

# %%
# scale
sc_ =  StandardScaler()
sc_.fit_transform(X_overfit)
# Out:
# array([[-0.07300932, -0.35530817, -2.20997115, ..., -0.33972273,
#         -0.01287683,  0.23670371],
#        [-0.77235568, -0.35530817,  0.26680468, ...,  0.97295558,
#          1.35198473,  0.6643518 ],
#        [ 0.69294147, -0.35530817,  0.26680468, ..., -0.85541779,
#         -0.90863356, -0.47961316],
#        ...,
#        [ 1.49219446,  0.58401759,  0.26680468, ...,  1.76993884,
#          0.90835165, -0.45777889],
#        [ 0.55973263, -0.35530817,  0.26680468, ..., -0.33972273,
#         -0.60509514, -0.68863735],
#        [-0.8389601 ,  0.58401759,  0.26680468, ...,  0.26973505,
#          0.67698321,  0.48871163]])

# %%
#alpha based on trial run.

lasso = Lasso(alpha=115.13953993264481,max_iter=10000, tol=.1)
lasso.fit(X_overfit,y_train)
lasso.score(X_overfit, y_train)
# Out:
# 0.9303088625839632

# %%
#increase pandas default max_rows so I can view all coef_ columns at once
pd.options.display.max_rows = 600

# %%
lasso_coef = lasso.coef_
poly_columns = poly.get_feature_names(X_train.columns)
pd.DataFrame(list(zip(poly_columns, lasso_coef)))
# Out:
#                                                      0             1
# 0                                                  age  -1178.419610
# 1                                   neighborhood_order   9573.758073
# 2                                     local_conditions     -0.000000
# 3                                        was_remodeled   9014.497862
# 4                                         overall_qual  11768.951267
# 5                            house_style_condensed_1.5     -0.000000
# 6                            house_style_condensed_2.0     -0.000000
# 7                                           exter_qual    331.955780
# 8                                     external_feature  -1173.696197
# 9                                     bldg_type_TwnhsE  -5765.216636
# 10                                     bldg_type_Twnhs     -0.000000
# 11                                    bldg_type_2fmCon      0.000000
# 12                                         is_hip_roof  15270.341760
# 13                                        mas_vnr_area     62.753454
# 14                                          functional     -0.000000
# 15                                        lot_frontage    480.874630
# 16                                            lot_area      1.168270
# 17                                developed_outside_sf     47.573984
# 18                                     garage_fin*sqft      0.613517
# 19                                         garage_cars     -0.000000
# 20                                         paved_drive  -4014.286081
# 21                                           bsmt_qual   -379.129819
# 22                                    bsmt_type*sf_all      2.641430
# 23                                       bsmt_exposure     -0.000000
# 24                                          heating_qc      0.000000
# 25                                        kitchen_qual     -0.000000
# 26                                        fireplace_qu   2057.778488
# 27                                  quality_above_sqft     12.999485
# 28                                       totrms_abvgrd   2880.322265
# 29                                           room_size    -12.596587
# 30                                               age^2      5.644123
# 31                              age neighborhood_order     73.368221
# 32                                age local_conditions     97.487201
# 33                                   age was_remodeled    -56.702455
# 34                                    age overall_qual    -16.499583
# 35                       age house_style_condensed_1.5     -9.686090
# 36                       age house_style_condensed_2.0     25.675168
# 37                                      age exter_qual     26.258960
# 38                                age external_feature     25.655288
# 39                                age bldg_type_TwnhsE    195.497501
# 40                                 age bldg_type_Twnhs    235.824250
# 41                                age bldg_type_2fmCon   -274.118899
# 42                                     age is_hip_roof   -245.683812
# 43                                    age mas_vnr_area     -1.086787
# 44                                      age functional    -36.951941
# 45                                    age lot_frontage     -1.699115
# 46                                        age lot_area     -0.006045
# 47                            age developed_outside_sf     -0.272477
# 48                                 age garage_fin*sqft     -0.060323
# 49                                     age garage_cars     38.799515
# 50                                     age paved_drive    163.135857
# 51                                       age bsmt_qual      4.632833
# 52                                age bsmt_type*sf_all      0.017756
# 53                                   age bsmt_exposure    -46.073102
# 54                                      age heating_qc     46.226589
# 55                                    age kitchen_qual    -40.711599
# 56                                    age fireplace_qu      3.885895
# 57                              age quality_above_sqft     -0.190776
# 58                                   age totrms_abvgrd     22.038005
# 59                                       age room_size      0.375305
# 60                                neighborhood_order^2   -347.061615
# 61                 neighborhood_order local_conditions   -834.697195
# 62                    neighborhood_order was_remodeled  -1244.732398
# 63                     neighborhood_order overall_qual    574.153470
# 64        neighborhood_order house_style_condensed_1.5    632.940669
# 65        neighborhood_order house_style_condensed_2.0      0.000000
# 66                       neighborhood_order exter_qual      0.065777
# 67                 neighborhood_order external_feature     11.691070
# 68                 neighborhood_order bldg_type_TwnhsE   -325.999656
# 69                  neighborhood_order bldg_type_Twnhs  -2330.854912
# 70                 neighborhood_order bldg_type_2fmCon      0.000000
# 71                      neighborhood_order is_hip_roof    197.558438
# 72                     neighborhood_order mas_vnr_area     -2.559462
# 73                       neighborhood_order functional   -326.697669
# 74                     neighborhood_order lot_frontage    -16.397874
# 75                         neighborhood_order lot_area     -0.139533
# 76             neighborhood_order developed_outside_sf      0.318040
# 77                  neighborhood_order garage_fin*sqft      3.918277
# 78                      neighborhood_order garage_cars   -854.933573
# 79                      neighborhood_order paved_drive  -2239.532221
# 80                        neighborhood_order bsmt_qual    478.465441
# 81                 neighborhood_order bsmt_type*sf_all      0.324484
# 82                    neighborhood_order bsmt_exposure   -205.795846
# 83                       neighborhood_order heating_qc   -187.837725
# 84                     neighborhood_order kitchen_qual    349.321776
# 85                     neighborhood_order fireplace_qu    420.118864
# 86               neighborhood_order quality_above_sqft      1.632321
# 87                    neighborhood_order totrms_abvgrd   -269.051130
# 88                        neighborhood_order room_size    -16.036537
# 89                                  local_conditions^2      0.000000
# 90                      local_conditions was_remodeled      9.506581
# 91                       local_conditions overall_qual   -285.197335
# 92          local_conditions house_style_condensed_1.5      0.000000
# 93          local_conditions house_style_condensed_2.0  -1784.902265
# 94                         local_conditions exter_qual    714.632620
# 95                   local_conditions external_feature     35.958993
# 96                   local_conditions bldg_type_TwnhsE     -0.000000
# 97                    local_conditions bldg_type_Twnhs     -0.000000
# 98                   local_conditions bldg_type_2fmCon     -0.000000
# 99                        local_conditions is_hip_roof    590.843767
# 100                      local_conditions mas_vnr_area      0.284900
# 101                        local_conditions functional      0.000000
# 102                      local_conditions lot_frontage    -69.895083
# 103                          local_conditions lot_area      0.225044
# 104              local_conditions developed_outside_sf     -0.400466
# 105                   local_conditions garage_fin*sqft      2.264302
# 106                       local_conditions garage_cars      0.000000
# 107                       local_conditions paved_drive     -0.707289
# 108                         local_conditions bsmt_qual     -2.861227
# 109                  local_conditions bsmt_type*sf_all      0.561273
# 110                     local_conditions bsmt_exposure    471.238317
# 111                        local_conditions heating_qc    206.556692
# 112                      local_conditions kitchen_qual    922.665885
# 113                      local_conditions fireplace_qu    151.736956
# 114                local_conditions quality_above_sqft      1.827926
# 115                     local_conditions totrms_abvgrd    -53.995150
# 116                         local_conditions room_size    -14.153873
# 117                                    was_remodeled^2   -305.374647
# 118                         was_remodeled overall_qual   -948.544082
# 119            was_remodeled house_style_condensed_1.5      0.000000
# 120            was_remodeled house_style_condensed_2.0      0.000000
# 121                           was_remodeled exter_qual   -177.752656
# 122                     was_remodeled external_feature   -368.968669
# 123                     was_remodeled bldg_type_TwnhsE     -0.000000
# 124                      was_remodeled bldg_type_Twnhs     -0.000000
# 125                     was_remodeled bldg_type_2fmCon      0.000000
# 126                          was_remodeled is_hip_roof     -0.000000
# 127                         was_remodeled mas_vnr_area      3.590567
# 128                           was_remodeled functional     -0.000000
# 129                         was_remodeled lot_frontage     26.999937
# 130                             was_remodeled lot_area      0.013361
# 131                 was_remodeled developed_outside_sf      0.780876
# 132                      was_remodeled garage_fin*sqft     -1.263491
# 133                          was_remodeled garage_cars      0.000000
# 134                          was_remodeled paved_drive  -1910.840043
# 135                            was_remodeled bsmt_qual    316.445979
# 136                     was_remodeled bsmt_type*sf_all     -0.410446
# 137                        was_remodeled bsmt_exposure      0.000000
# 138                           was_remodeled heating_qc    383.533764
# 139                         was_remodeled kitchen_qual   1196.132885
# 140                         was_remodeled fireplace_qu   1100.897811
# 141                   was_remodeled quality_above_sqft      2.899502
# 142                        was_remodeled totrms_abvgrd   -208.707167
# 143                            was_remodeled room_size      5.143078
# 144                                     overall_qual^2    -72.807362
# 145             overall_qual house_style_condensed_1.5  -1158.457610
# 146             overall_qual house_style_condensed_2.0   -681.924474
# 147                            overall_qual exter_qual    149.358751
# 148                      overall_qual external_feature    -18.706248
# 149                      overall_qual bldg_type_TwnhsE      0.000000
# 150                       overall_qual bldg_type_Twnhs   -493.984446
# 151                      overall_qual bldg_type_2fmCon      0.000000
# 152                           overall_qual is_hip_roof    -45.781848
# 153                          overall_qual mas_vnr_area     -0.257881
# 154                            overall_qual functional   -443.442959
# 155                          overall_qual lot_frontage     -9.325186
# 156                              overall_qual lot_area     -0.022880
# 157                  overall_qual developed_outside_sf      0.622730
# 158                       overall_qual garage_fin*sqft      1.016005
# 159                           overall_qual garage_cars     96.462141
# 160                           overall_qual paved_drive  -1260.513797
# 161                             overall_qual bsmt_qual    198.877914
# 162                      overall_qual bsmt_type*sf_all      0.065101
# 163                         overall_qual bsmt_exposure     74.443605
# 164                            overall_qual heating_qc    -84.925044
# 165                          overall_qual kitchen_qual    198.664438
# 166                          overall_qual fireplace_qu     45.375047
# 167                    overall_qual quality_above_sqft      1.020309
# 168                         overall_qual totrms_abvgrd   -112.057472
# 169                             overall_qual room_size     -6.093240
# 170                        house_style_condensed_1.5^2     -0.000000
# 171  house_style_condensed_1.5 house_style_condense...      0.000000
# 172               house_style_condensed_1.5 exter_qual     -0.000000
# 173         house_style_condensed_1.5 external_feature  -1118.226688
# 174         house_style_condensed_1.5 bldg_type_TwnhsE      0.000000
# 175          house_style_condensed_1.5 bldg_type_Twnhs      0.000000
# 176         house_style_condensed_1.5 bldg_type_2fmCon      0.000000
# 177              house_style_condensed_1.5 is_hip_roof     -0.000000
# 178             house_style_condensed_1.5 mas_vnr_area     43.625890
# 179               house_style_condensed_1.5 functional     -0.000000
# 180             house_style_condensed_1.5 lot_frontage     42.397698
# 181                 house_style_condensed_1.5 lot_area      0.399933
# 182     house_style_condensed_1.5 developed_outside_sf     -1.925135
# 183          house_style_condensed_1.5 garage_fin*sqft     -1.341743
# 184              house_style_condensed_1.5 garage_cars      0.000000
# 185              house_style_condensed_1.5 paved_drive     -0.000000
# 186                house_style_condensed_1.5 bsmt_qual    397.446557
# 187         house_style_condensed_1.5 bsmt_type*sf_all     -1.093136
# 188            house_style_condensed_1.5 bsmt_exposure   1085.610640
# 189               house_style_condensed_1.5 heating_qc    880.267454
# 190             house_style_condensed_1.5 kitchen_qual      0.000000
# 191             house_style_condensed_1.5 fireplace_qu      0.000000
# 192       house_style_condensed_1.5 quality_above_sqft    -10.551756
# 193            house_style_condensed_1.5 totrms_abvgrd   1539.829100
# 194                house_style_condensed_1.5 room_size     29.890304
# 195                        house_style_condensed_2.0^2     -0.000000
# 196               house_style_condensed_2.0 exter_qual  -1756.066377
# 197         house_style_condensed_2.0 external_feature     -0.000000
# 198         house_style_condensed_2.0 bldg_type_TwnhsE      0.000000
# 199          house_style_condensed_2.0 bldg_type_Twnhs     -0.000000
# 200         house_style_condensed_2.0 bldg_type_2fmCon     -0.000000
# 201              house_style_condensed_2.0 is_hip_roof      0.000000
# 202             house_style_condensed_2.0 mas_vnr_area     -2.474589
# 203               house_style_condensed_2.0 functional    628.713173
# 204             house_style_condensed_2.0 lot_frontage     90.632201
# 205                 house_style_condensed_2.0 lot_area     -0.071075
# 206     house_style_condensed_2.0 developed_outside_sf     -5.998649
# 207          house_style_condensed_2.0 garage_fin*sqft      0.547676
# 208              house_style_condensed_2.0 garage_cars     -0.000000
# 209              house_style_condensed_2.0 paved_drive   -792.366484
# 210                house_style_condensed_2.0 bsmt_qual      0.000000
# 211         house_style_condensed_2.0 bsmt_type*sf_all      0.649004
# 212            house_style_condensed_2.0 bsmt_exposure   -326.268830
# 213               house_style_condensed_2.0 heating_qc   -135.018152
# 214             house_style_condensed_2.0 kitchen_qual      0.000000
# 215             house_style_condensed_2.0 fireplace_qu      0.000000
# 216       house_style_condensed_2.0 quality_above_sqft      3.479921
# 217            house_style_condensed_2.0 totrms_abvgrd   -333.289588
# 218                house_style_condensed_2.0 room_size     -9.740235
# 219                                       exter_qual^2     67.629895
# 220                        exter_qual external_feature      8.630847
# 221                        exter_qual bldg_type_TwnhsE     -0.000000
# 222                         exter_qual bldg_type_Twnhs     -0.000000
# 223                        exter_qual bldg_type_2fmCon     -0.000000
# 224                             exter_qual is_hip_roof     -0.000000
# 225                            exter_qual mas_vnr_area     -2.320822
# 226                              exter_qual functional      0.000000
# 227                            exter_qual lot_frontage    -31.021076
# 228                                exter_qual lot_area     -0.067927
# 229                    exter_qual developed_outside_sf     -0.167387
# 230                         exter_qual garage_fin*sqft      0.723466
# 231                             exter_qual garage_cars    319.915798
# 232                             exter_qual paved_drive    -58.849906
# 233                               exter_qual bsmt_qual    132.044023
# 234                        exter_qual bsmt_type*sf_all     -0.089841
# 235                           exter_qual bsmt_exposure     72.825748
# 236                              exter_qual heating_qc     -1.028016
# 237                            exter_qual kitchen_qual    357.361452
# 238                            exter_qual fireplace_qu   -187.703066
# 239                      exter_qual quality_above_sqft      2.013420
# 240                           exter_qual totrms_abvgrd   -134.817296
# 241                               exter_qual room_size     -2.007265
# 242                                 external_feature^2    -97.393542
# 243                  external_feature bldg_type_TwnhsE    -16.840843
# 244                   external_feature bldg_type_Twnhs    -75.426653
# 245                  external_feature bldg_type_2fmCon   2278.590325
# 246                       external_feature is_hip_roof      0.000000
# 247                      external_feature mas_vnr_area      0.113528
# 248                        external_feature functional    882.560990
# 249                      external_feature lot_frontage     -3.669297
# 250                          external_feature lot_area      0.043986
# 251              external_feature developed_outside_sf     -2.222288
# 252                   external_feature garage_fin*sqft     -0.304834
# 253                       external_feature garage_cars    185.797538
# 254                       external_feature paved_drive     22.692101
# 255                         external_feature bsmt_qual     18.966703
# 256                  external_feature bsmt_type*sf_all     -0.024033
# 257                     external_feature bsmt_exposure    -22.338063
# 258                        external_feature heating_qc     81.801386
# 259                      external_feature kitchen_qual     72.531190
# 260                      external_feature fireplace_qu     -8.489230
# 261                external_feature quality_above_sqft      0.712199
# 262                     external_feature totrms_abvgrd    -19.928974
# 263                         external_feature room_size     -0.434651
# 264                                 bldg_type_TwnhsE^2      0.000000
# 265                   bldg_type_TwnhsE bldg_type_Twnhs      0.000000
# 266                  bldg_type_TwnhsE bldg_type_2fmCon      0.000000
# 267                       bldg_type_TwnhsE is_hip_roof     -0.000000
# 268                      bldg_type_TwnhsE mas_vnr_area     20.234508
# 269                        bldg_type_TwnhsE functional      0.000000
# 270                      bldg_type_TwnhsE lot_frontage   -124.783445
# 271                          bldg_type_TwnhsE lot_area      0.178087
# 272              bldg_type_TwnhsE developed_outside_sf    -39.647542
# 273                   bldg_type_TwnhsE garage_fin*sqft      1.139577
# 274                       bldg_type_TwnhsE garage_cars     -0.000000
# 275                       bldg_type_TwnhsE paved_drive      0.000000
# 276                         bldg_type_TwnhsE bsmt_qual      0.000000
# 277                  bldg_type_TwnhsE bsmt_type*sf_all     -0.162759
# 278                     bldg_type_TwnhsE bsmt_exposure    220.834255
# 279                        bldg_type_TwnhsE heating_qc    970.177917
# 280                      bldg_type_TwnhsE kitchen_qual      0.000000
# 281                      bldg_type_TwnhsE fireplace_qu      0.000000
# 282                bldg_type_TwnhsE quality_above_sqft      7.332714
# 283                     bldg_type_TwnhsE totrms_abvgrd   -187.879992
# 284                         bldg_type_TwnhsE room_size     -7.180689
# 285                                  bldg_type_Twnhs^2      0.000000
# 286                   bldg_type_Twnhs bldg_type_2fmCon      0.000000
# 287                        bldg_type_Twnhs is_hip_roof     -0.000000
# 288                       bldg_type_Twnhs mas_vnr_area     28.889911
# 289                         bldg_type_Twnhs functional      0.000000
# 290                       bldg_type_Twnhs lot_frontage   -146.567403
# 291                           bldg_type_Twnhs lot_area      2.867120
# 292               bldg_type_Twnhs developed_outside_sf    -17.309608
# 293                    bldg_type_Twnhs garage_fin*sqft    -12.575005
# 294                        bldg_type_Twnhs garage_cars      0.000000
# 295                        bldg_type_Twnhs paved_drive      0.000000
# 296                          bldg_type_Twnhs bsmt_qual      0.000000
# 297                   bldg_type_Twnhs bsmt_type*sf_all     -1.864373
# 298                      bldg_type_Twnhs bsmt_exposure      0.000000
# 299                         bldg_type_Twnhs heating_qc      0.000000
# 300                       bldg_type_Twnhs kitchen_qual      0.000000
# 301                       bldg_type_Twnhs fireplace_qu      0.000000
# 302                 bldg_type_Twnhs quality_above_sqft      8.146993
# 303                      bldg_type_Twnhs totrms_abvgrd      0.000000
# 304                          bldg_type_Twnhs room_size     24.347954
# 305                                 bldg_type_2fmCon^2      0.000000
# 306                       bldg_type_2fmCon is_hip_roof      0.000000
# 307                      bldg_type_2fmCon mas_vnr_area    126.424798
# 308                        bldg_type_2fmCon functional      0.000000
# 309                      bldg_type_2fmCon lot_frontage   -114.904498
# 310                          bldg_type_2fmCon lot_area      0.339383
# 311              bldg_type_2fmCon developed_outside_sf     46.826449
# 312                   bldg_type_2fmCon garage_fin*sqft    -18.529313
# 313                       bldg_type_2fmCon garage_cars     -0.000000
# 314                       bldg_type_2fmCon paved_drive     -0.000000
# 315                         bldg_type_2fmCon bsmt_qual     -0.000000
# 316                  bldg_type_2fmCon bsmt_type*sf_all     -1.342005
# 317                     bldg_type_2fmCon bsmt_exposure      0.000000
# 318                        bldg_type_2fmCon heating_qc      0.000000
# 319                      bldg_type_2fmCon kitchen_qual     -0.000000
# 320                      bldg_type_2fmCon fireplace_qu      0.000000
# 321                bldg_type_2fmCon quality_above_sqft      0.133049
# 322                     bldg_type_2fmCon totrms_abvgrd    454.981381
# 323                         bldg_type_2fmCon room_size     22.430105
# 324                                      is_hip_roof^2     -0.000000
# 325                           is_hip_roof mas_vnr_area     10.997141
# 326                             is_hip_roof functional      0.000000
# 327                           is_hip_roof lot_frontage   -103.279024
# 328                               is_hip_roof lot_area      0.536380
# 329                   is_hip_roof developed_outside_sf     -2.665710
# 330                        is_hip_roof garage_fin*sqft     -7.462640
# 331                            is_hip_roof garage_cars     -0.000000
# 332                            is_hip_roof paved_drive   -217.330239
# 333                              is_hip_roof bsmt_qual   -126.746384
# 334                       is_hip_roof bsmt_type*sf_all     -1.133852
# 335                          is_hip_roof bsmt_exposure     14.120322
# 336                             is_hip_roof heating_qc   1126.068327
# 337                           is_hip_roof kitchen_qual    807.272747
# 338                           is_hip_roof fireplace_qu   -826.576509
# 339                     is_hip_roof quality_above_sqft      4.355443
# 340                          is_hip_roof totrms_abvgrd      0.000000
# 341                              is_hip_roof room_size    -22.914670
# 342                                     mas_vnr_area^2     -0.011064
# 343                            mas_vnr_area functional    -17.501733
# 344                          mas_vnr_area lot_frontage      0.357591
# 345                              mas_vnr_area lot_area     -0.000909
# 346                  mas_vnr_area developed_outside_sf     -0.033322
# 347                       mas_vnr_area garage_fin*sqft      0.001547
# 348                           mas_vnr_area garage_cars      5.147681
# 349                           mas_vnr_area paved_drive    -11.128919
# 350                             mas_vnr_area bsmt_qual      2.811503
# 351                      mas_vnr_area bsmt_type*sf_all     -0.000257
# 352                         mas_vnr_area bsmt_exposure      4.029141
# 353                            mas_vnr_area heating_qc     -1.406539
# 354                          mas_vnr_area kitchen_qual      1.520349
# 355                          mas_vnr_area fireplace_qu      1.369462
# 356                    mas_vnr_area quality_above_sqft     -0.001531
# 357                         mas_vnr_area totrms_abvgrd     -0.189557
# 358                             mas_vnr_area room_size     -0.055188
# 359                                       functional^2      0.000000
# 360                            functional lot_frontage     47.195727
# 361                                functional lot_area     -0.136945
# 362                    functional developed_outside_sf    -13.217369
# 363                         functional garage_fin*sqft     -2.592391
# 364                             functional garage_cars     -0.000000
# 365                             functional paved_drive    180.971800
# 366                               functional bsmt_qual    144.499576
# 367                        functional bsmt_type*sf_all      1.411867
# 368                           functional bsmt_exposure      0.000000
# 369                              functional heating_qc     -0.000000
# 370                            functional kitchen_qual   -269.780421
# 371                            functional fireplace_qu  -1728.355832
# 372                      functional quality_above_sqft     10.849452
# 373                           functional totrms_abvgrd   -317.707304
# 374                               functional room_size      3.531143
# 375                                     lot_frontage^2     -0.436651
# 376                              lot_frontage lot_area     -0.003336
# 377                  lot_frontage developed_outside_sf     -0.174559
# 378                       lot_frontage garage_fin*sqft      0.016815
# 379                           lot_frontage garage_cars     -0.082771
# 380                           lot_frontage paved_drive     40.652875
# 381                             lot_frontage bsmt_qual     -0.915900
# 382                      lot_frontage bsmt_type*sf_all     -0.018774
# 383                         lot_frontage bsmt_exposure      0.175344
# 384                            lot_frontage heating_qc     -3.478988
# 385                          lot_frontage kitchen_qual     29.824602
# 386                          lot_frontage fireplace_qu     11.944762
# 387                    lot_frontage quality_above_sqft     -0.017136
# 388                         lot_frontage totrms_abvgrd     -1.233624
# 389                             lot_frontage room_size      0.103493
# 390                                         lot_area^2     -0.000005
# 391                      lot_area developed_outside_sf      0.000284
# 392                           lot_area garage_fin*sqft     -0.000185
# 393                               lot_area garage_cars      0.121625
# 394                               lot_area paved_drive      0.302241
# 395                                 lot_area bsmt_qual      0.015646
# 396                          lot_area bsmt_type*sf_all     -0.000010
# 397                             lot_area bsmt_exposure      0.070526
# 398                                lot_area heating_qc     -0.006437
# 399                              lot_area kitchen_qual     -0.040469
# 400                              lot_area fireplace_qu     -0.009705
# 401                        lot_area quality_above_sqft     -0.000095
# 402                             lot_area totrms_abvgrd     -0.010841
# 403                                 lot_area room_size      0.000799
# 404                             developed_outside_sf^2     -0.000638
# 405               developed_outside_sf garage_fin*sqft     -0.004669
# 406                   developed_outside_sf garage_cars      5.065947
# 407                   developed_outside_sf paved_drive     -5.791808
# 408                     developed_outside_sf bsmt_qual     -0.558955
# 409              developed_outside_sf bsmt_type*sf_all     -0.003106
# 410                 developed_outside_sf bsmt_exposure      3.993576
# 411                    developed_outside_sf heating_qc      2.302748
# 412                  developed_outside_sf kitchen_qual      4.625010
# 413                  developed_outside_sf fireplace_qu      1.907110
# 414            developed_outside_sf quality_above_sqft      0.009522
# 415                 developed_outside_sf totrms_abvgrd     -3.646463
# 416                     developed_outside_sf room_size      0.052203
# 417                                  garage_fin*sqft^2     -0.000567
# 418                        garage_fin*sqft garage_cars     -0.718393
# 419                        garage_fin*sqft paved_drive     -3.666471
# 420                          garage_fin*sqft bsmt_qual      0.804883
# 421                   garage_fin*sqft bsmt_type*sf_all     -0.000132
# 422                      garage_fin*sqft bsmt_exposure      1.430449
# 423                         garage_fin*sqft heating_qc     -1.280608
# 424                       garage_fin*sqft kitchen_qual      0.805856
# 425                       garage_fin*sqft fireplace_qu     -0.635738
# 426                 garage_fin*sqft quality_above_sqft      0.003694
# 427                      garage_fin*sqft totrms_abvgrd     -0.432744
# 428                          garage_fin*sqft room_size     -0.014351
# 429                                      garage_cars^2    415.434439
# 430                            garage_cars paved_drive   -108.579320
# 431                              garage_cars bsmt_qual     96.766995
# 432                       garage_cars bsmt_type*sf_all      0.203131
# 433                          garage_cars bsmt_exposure   -338.200240
# 434                             garage_cars heating_qc   -477.775985
# 435                           garage_cars kitchen_qual    407.112312
# 436                           garage_cars fireplace_qu     59.125650
# 437                     garage_cars quality_above_sqft      0.238885
# 438                          garage_cars totrms_abvgrd   -106.851635
# 439                              garage_cars room_size     -8.316818
# 440                                      paved_drive^2    197.965695
# 441                              paved_drive bsmt_qual      6.637902
# 442                       paved_drive bsmt_type*sf_all      0.018084
# 443                          paved_drive bsmt_exposure      0.000000
# 444                             paved_drive heating_qc    -11.231173
# 445                           paved_drive kitchen_qual    -58.054050
# 446                           paved_drive fireplace_qu   -131.969170
# 447                     paved_drive quality_above_sqft     -0.137458
# 448                          paved_drive totrms_abvgrd     -0.000000
# 449                              paved_drive room_size     18.925077
# 450                                        bsmt_qual^2   -400.368205
# 451                         bsmt_qual bsmt_type*sf_all      0.120772
# 452                            bsmt_qual bsmt_exposure      0.000000
# 453                               bsmt_qual heating_qc    -52.200066
# 454                             bsmt_qual kitchen_qual    178.160829
# 455                             bsmt_qual fireplace_qu     67.121110
# 456                       bsmt_qual quality_above_sqft      1.138391
# 457                            bsmt_qual totrms_abvgrd      4.170255
# 458                                bsmt_qual room_size     -5.956853
# 459                                 bsmt_type*sf_all^2      0.000204
# 460                     bsmt_type*sf_all bsmt_exposure     -0.133331
# 461                        bsmt_type*sf_all heating_qc     -0.228366
# 462                      bsmt_type*sf_all kitchen_qual      0.066744
# 463                      bsmt_type*sf_all fireplace_qu      0.302931
# 464                bsmt_type*sf_all quality_above_sqft      0.000020
# 465                     bsmt_type*sf_all totrms_abvgrd     -0.105798
# 466                         bsmt_type*sf_all room_size     -0.002017
# 467                                    bsmt_exposure^2     33.257364
# 468                           bsmt_exposure heating_qc   -279.347144
# 469                         bsmt_exposure kitchen_qual      9.551803
# 470                         bsmt_exposure fireplace_qu    487.148496
# 471                   bsmt_exposure quality_above_sqft      1.340295
# 472                        bsmt_exposure totrms_abvgrd   -292.403604
# 473                            bsmt_exposure room_size     -1.466125
# 474                                       heating_qc^2     16.790982
# 475                            heating_qc kitchen_qual   -107.527279
# 476                            heating_qc fireplace_qu   -450.025063
# 477                      heating_qc quality_above_sqft      1.024166
# 478                           heating_qc totrms_abvgrd     72.225222
# 479                               heating_qc room_size      4.568743
# 480                                     kitchen_qual^2    -45.457948
# 481                          kitchen_qual fireplace_qu   -102.541864
# 482                    kitchen_qual quality_above_sqft     -0.255091
# 483                         kitchen_qual totrms_abvgrd      0.778068
# 484                             kitchen_qual room_size      1.130481
# 485                                     fireplace_qu^2     15.918475
# 486                    fireplace_qu quality_above_sqft      1.145796
# 487                         fireplace_qu totrms_abvgrd   -170.664029
# 488                             fireplace_qu room_size     -1.770734
# 489                               quality_above_sqft^2     -0.000321
# 490                   quality_above_sqft totrms_abvgrd     -0.752068
# 491                       quality_above_sqft room_size      0.011347
# 492                                    totrms_abvgrd^2     51.111442
# 493                            totrms_abvgrd room_size     -3.554982
# 494                                        room_size^2      0.137323

# %% [markdown]
# ## Ridge Model

# %%
#create pipeline for ridge model

pipe_ridge = Pipeline([
    ('sc', StandardScaler()),
    ('ridge', Ridge())
])

# %%
#create parameters for gridsearch
ridge_params1 = {'ridge__alpha':np.logspace(-1, 3, 50),
                'ridge__max_iter':[1000]}

# %%
#apply pipeline and gridsearch to GridSearchCV
pipe_ridge_gridsearch = GridSearchCV(
                                 pipe_ridge, 
                                 param_grid=ridge_params1,
                             )

# %%
#fit best result from grid search

pipe_ridge_gridsearch.fit(X_train, y_train)
pipe_ridge_gridsearch.best_estimator_
# Out:
# Pipeline(steps=[('sc', StandardScaler()),
#                 ('ridge', Ridge(alpha=15.998587196060573, max_iter=1000))])

# %%
pipe_ridge_gridsearch.best_score_ #this models score
# Out:
# 0.8942149238176663

# %%
preds_ridge = pipe_ridge_gridsearch.predict(X_test)

# %%
ames_eval['saleprice_ridge'] = preds_ridge
ridge_submission = ames_eval[['id', 'saleprice_ridge']]
# Out:
# C:\Users\KELVIN~1.LIE\AppData\Local\Temp/ipykernel_21472/392335949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ames_eval['saleprice_ridge'] = preds_ridge

# %%
ridge_submission.head(3)
# Out:
#      id  saleprice_ridge
# 0  2658    127138.870675
# 1  2718    172497.172321
# 2  2414    217226.054320

# %%
#ridge submission file
csv_ames = r'C:\myLib\IOD\Classwork\Mini Project 2\ames_ridge_submission.csv'.replace('\\','/')
ridge_submission.to_csv(csv_ames, index = False)

# %% [markdown]
# ## ElasticNetCV Model --best of both worlds

# %%
pipe_mario = Pipeline([
            ('poly', PolynomialFeatures(degree=3)),
            ('sc', StandardScaler()),
            ('elasticnet', ElasticNet())
                        ])

# %%
parameters_mario = {'elasticnet__alpha': np.logspace(-1, 2.5, 100),
                      'elasticnet__normalize': [True],
                      'elasticnet__selection': ['random'],
                        'elasticnet__max_iter': [10000],
                        'elasticnet__tol': [.01],
                        'elasticnet__warm_start': [True]
                       }

# %%
elastic_net_model = GridSearchCV(
                pipe_mario, 
           param_grid= parameters_mario)
elastic_net_model.fit(X_train, y_train)
elastic_net_model.best_estimator_
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=3)),
#                 ('sc', StandardScaler()),
#                 ('elasticnet',
#                  ElasticNet(alpha=0.1, max_iter=10000, normalize=True,
#                             selection='random', tol=0.01, warm_start=True))])

# %%
elastic_net_model.best_score_
# Out:
# 0.8962851515375851

# %%
preds_elastic_net_model = elastic_net_model.predict(X_test)

# %%
ames_eval['SalePrice'] = preds_elastic_net_model
submission = ames_eval[['id', 'SalePrice']]
submission.head(3)
# Out:
# C:\Users\KELVIN~1.LIE\AppData\Local\Temp/ipykernel_21472/116688702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ames_eval['SalePrice'] = preds_elastic_net_model
#      id      SalePrice
# 0  2658  122824.080640
# 1  2718  162007.977480
# 2  2414  218416.985105

# %%
#elastic net submission
csv_ames = r'C:\myLib\IOD\Classwork\Mini Project 2\ames_elasticnet_submission.csv'.replace('\\','/')
submission.to_csv(csv_ames, index = False)
